# %% [markdown]
# Option Pricing Model

# %%
from polygon import RESTClient
from dotenv import load_dotenv
import pandas as pd
import os

#Configure REST API Client with API Key Environment Variables
load_dotenv()

POLYGON_API_KEY = os.getenv("POLYGON_API_KEY")

client = RESTClient(POLYGON_API_KEY) 

response_financials = client.reference_stock_financials('AAPL',timeframe="quarterly")
response = client.stocks_equities_aggregates('AAPL', multiplier=1, timespan='day', from_='2020-07-22', to='2022-08-22')

response_df = pd.DataFrame(response.results)

response_df.head()

client.
# Out:
#   ticker period calendarDate reportPeriod     updated     dateKey  \
# 0   AAPL     QA   2020-03-31   2020-03-28  2020-05-01  2020-03-28
# 1   AAPL     TA   2020-03-31   2020-03-28  2020-05-01  2020-03-28
# 2   AAPL      T   2020-03-31   2020-03-28  2020-05-01  2020-05-01
# 3   AAPL      Q   2020-03-31   2020-03-28  2020-05-01  2020-05-01
# 4   AAPL      Q   2019-12-31   2019-12-28  2020-05-01  2020-01-29
#
#    accumulatedOtherComprehensiveIncome        assets  assetsCurrent  \
# 0                        -2.789000e+09  3.204000e+11   1.437530e+11
# 1                        -2.789000e+09  3.204000e+11   1.437530e+11
# 2                        -2.789000e+09  3.204000e+11   1.437530e+11
# 3                        -2.789000e+09  3.204000e+11   1.437530e+11
# 4                        -4.180000e+08  3.406180e+11   1.632310e+11
#
#    assetsNonCurrent  ...  tangibleAssetsBookValuePerShare  workingCapital  \
# 0      1.766470e+11  ...                           73.485    4.765900e+10
# ...
